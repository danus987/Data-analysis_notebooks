# %%
import pandas as pd

# %%
df=pd.read_csv('forbes_global_2010_2014.txt',sep='\t')
# Out:
#                           company                  sector  \
# 0                            ICBC              Financials
# 1         China Construction Bank              Financials
# 2      Agricultural Bank of China              Financials
# 3                  JPMorgan Chase              Financials
# 4              Berkshire Hathaway              Financials
# ..                            ...                     ...
# 99                    Walt Disney  Consumer Discretionary
# 100                      Barclays              Financials
# 101    LifeShield Assurance Group              Financials
# 102  EnergyPro Electric Utilities               Utilities
# 103    RetailCare Health Supplies        Consumer Staples
#
#                     industry      continent         country  marketvalue  \
# 0                Major Banks           Asia           China        215.6
# 1             Regional Banks           Asia           China        174.4
# ...

# %%
# df[df['sector']=='Financials'].sort_values('profits',ascending=False)
# df.iloc[[0]][['company','continent']]  
# same results 

df['rank']=df['profits'].rank(method='min',ascending=False)
result=df[df['rank']==1][['company','continent']]
result
# Out:
#   company continent
# 0    ICBC      Asia
