# %%
import pandas as pd

# %%
fraud_score = pd.read_csv('fraud_score.txt',sep='\t')

# %%
fraud_score['rank']=fraud_score.groupby('state').rank(method='first',ascending=False)['fraud_score']

# %%
result = fraud_score[fraud_score['rank']<=5]
result
# Out:
#     policy_num state  claim_cost  fraud_score  rank
# 15    ABCD1016    CA        1639         0.96   2.0
# 20    ABCD1021    CA        4898         0.95   4.0
# 26    ABCD1027    CA        2663         0.99   1.0
# 68    ABCD1069    CA        1426         0.95   5.0
# 78    ABCD1079    CA        4224         0.96   3.0
# 116   ABCD1117    NY        4903         0.98   1.0
# 120   ABCD1121    NY        4009         0.97   4.0
# 124   ABCD1125    NY        1904         0.97   5.0
# 186   ABCD1187    NY        3722         0.98   2.0
# 188   ABCD1189    NY        3577         0.98   3.0
# 208   ABCD1209    FL        4061         0.92   4.0
# 211   ABCD1212    FL        2956         0.92   5.0
# 217   ABCD1218    FL        1419         0.96   2.0
# 221   ABCD1222    FL        2392         0.99   1.0
# 290   ABCD1291    FL        2581         0.94   3.0
# 303   ABCD1304    TX        1407         1.00   1.0
# 360   ABCD1361    TX        4950         1.00   2.0
# ...
