# %%
import pandas as pd

# %%
df = pd.read_csv('yelp_business.txt',sep='\t')
df
# Out:
#                business_id                             name neighborhood  \
# 0   G5ERFWvPfHy7IDAUYlWL2A  All Colors Mobile Bumper Repair          NaN
# 1   0jDvRJS-z9zdMgOUXgr6rA                          Sunfare          NaN
# 2   6HmDqeNNZtHMK0t2glF_gg                  Dry Clean Vegas    Southeast
# 3   pbt3SBcEmxCfZPdnmU9tNA                The Cuyahoga Room          NaN
# 4   CX8pfLn7Bk9o2-8yDMp_2w                    The UPS Store          NaN
# ..                     ...                              ...          ...
# 95  l4xrBZAKLXpSR4iprqTw8A                           Mark's          NaN
# 96  ICdzSGuv70gpSk7aqpIrHw                       Wok-In Bbq          NaN
# 97  wk3wGDfJb1V-ciZpyhoNAA              Bic's Pub and Grill          NaN
# 98  NBYN4Nks_EsPHyAlJ_mdNw                    Bistro Merlot          NaN
# 99  xPy6fq53MdGMxtbvxBD4RA                      The Addison          NaN
#
#                                address            city state postal_code  \
# ...

# %%
df['rank']=df['review_count'].rank(method='first',ascending=False)

# %%
df=df.sort_values('rank').head(5)
results = df[['name','review_count']]
results
# Out:
#                          name  review_count
# 68                  Iron Chef           331
# 88  Jacs Dining and Tap House           197
# 63        Grimaldi's Pizzeria           187
# 84           Signs Restaurant           120
# 86                   Kassab's           101
