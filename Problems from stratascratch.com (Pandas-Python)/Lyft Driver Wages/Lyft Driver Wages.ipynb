# %%
import pandas as pd

# %%
df = pd.read_csv('lyft_drivers.txt',sep='\t')

# %%
results = df[(df['yearly_salary']<=30000) | (df['yearly_salary']>=70000)]

# %%
results
# Out:
#     index  start_date    end_date  yearly_salary
# 10     10  2018-04-25  2018-04-28          79536
# 14     14  2015-11-30  2018-04-24          89270
# 15     15  2018-05-29         NaN          87766
# 17     17  2017-05-07         NaN          88828
# 18     18  2018-11-09         NaN          82993
# 20     20  2015-04-23  2017-01-30          71683
# 22     22  2016-12-25         NaN          85329
# 23     23  2015-05-11  2018-03-29          72366
# 24     24  2018-03-24  2019-01-04          84812
# 26     26  2016-05-12  2018-10-02          88599
# 27     27  2017-03-26         NaN          85792
# 29     29  2016-03-30  2018-08-10          29866
# 31     31  2016-11-01         NaN          82028
# 35     35  2018-10-19  2018-11-23          90920
# 41     41  2017-06-27  2017-12-29          90137
# 47     47  2018-06-12         NaN          76924
# 49     49  2015-10-06  2016-11-27          27194
# 55     55  2016-12-02         NaN          29542
# ...
